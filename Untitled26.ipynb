# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
#from keras_layer_normalization import LayerNormalization
from tensorflow.python.keras.layers.normalization import BatchNormalization
from tensorflow.python.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPool2D
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical # convert to one-hot-encoding

# %%
## If you are using the data by mounting the google drive, use the following :

# from google.colab import drive
# drive.mount('/content/gdrive')

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
root_path = 'dataset'
data_dir_train = pathlib.Path(root_path + '/Train')
data_dir_test = pathlib.Path(root_path + '/Test')
data_dir_train
# Out:
# WindowsPath('dataset/Train')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
## Write your test dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_test,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 118 files belonging to 9 classes.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
preprocessing_layers = [
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(180, 180, 3))
]

# %%
### Your code goes here

input_shape = (180,180,3)
lr = 1e-5
init = 'normal'
activ = 'relu'

model = Sequential()
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(180, 180, 3)))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

## Number of classes is 9
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_1 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 178, 178, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 176, 176, 32)      9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 88, 88, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 86, 86, 64)        18496
# _________________________________________________________________
# batch_normalization (BatchNo (None, 86, 86, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 43, 43, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 41, 41, 128)       73856
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 41, 41, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 20, 20, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               26214912
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 26,318,689
# Trainable params: 26,318,305
# Non-trainable params: 384
# _________________________________________________________________

# %%
### Todo, choose an appropirate optimiser and loss function

optimizer = 'adam'
loss_fn = "binary_crossentropy"
model.compile(optimizer=optimizer,
              loss=loss_fn,
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_1 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 178, 178, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 176, 176, 32)      9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 88, 88, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 86, 86, 64)        18496
# _________________________________________________________________
# batch_normalization (BatchNo (None, 86, 86, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 43, 43, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 41, 41, 128)       73856
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 41, 41, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 20, 20, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               26214912
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 26,318,689
# Trainable params: 26,318,305
# Non-trainable params: 384
# _________________________________________________________________

# %%
epochs = 20
batch_size = 32

history = model.fit(
  train_ds,
  batch_size=batch_size,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 84s 1s/step - loss: -70129.7656 - accuracy: 0.1691 - val_loss: -69692.1719 - val_accuracy: 0.1499
# Epoch 2/20
# 56/56 [==============================] - 76s 1s/step - loss: -835582.3125 - accuracy: 0.1724 - val_loss: -882383.6250 - val_accuracy: 0.1499
# Epoch 3/20
# 56/56 [==============================] - 78s 1s/step - loss: -3100537.5000 - accuracy: 0.1724 - val_loss: -3916442.2500 - val_accuracy: 0.1499
# Epoch 4/20
# 56/56 [==============================] - 74s 1s/step - loss: -7649317.0000 - accuracy: 0.1724 - val_loss: -8081688.0000 - val_accuracy: 0.1499
# Epoch 5/20
# 56/56 [==============================] - 74s 1s/step - loss: -15100090.0000 - accuracy: 0.1724 - val_loss: -16237023.0000 - val_accuracy: 0.1499
# Epoch 6/20
# 56/56 [==============================] - 74s 1s/step - loss: -26374666.0000 - accuracy: 0.1724 - val_loss: -28336752.0000 - val_accuracy: 0.1499
# Epoch 7/20
# 56/56 [==============================] - 75s 1s/step - loss: -41887572.0000 - accuracy: 0.1724 - val_loss: -46761268.0000 - val_accuracy: 0.1499
# Epoch 8/20
# 56/56 [==============================] - 76s 1s/step - loss: -62495976.0000 - accuracy: 0.1724 - val_loss: -54837008.0000 - val_accuracy: 0.1499
# Epoch 9/20
# 56/56 [==============================] - 76s 1s/step - loss: -89033088.0000 - accuracy: 0.1724 - val_loss: -110543536.0000 - val_accuracy: 0.1499
# Epoch 10/20
# 56/56 [==============================] - 84s 1s/step - loss: -120907000.0000 - accuracy: 0.1724 - val_loss: -136529808.0000 - val_accuracy: 0.1499
# Epoch 11/20
# 56/56 [==============================] - 84s 2s/step - loss: -160833952.0000 - accuracy: 0.1724 - val_loss: -135113520.0000 - val_accuracy: 0.1499
# Epoch 12/20
# 56/56 [==============================] - 80s 1s/step - loss: -204105376.0000 - accuracy: 0.1724 - val_loss: -254890208.0000 - val_accuracy: 0.1499
# Epoch 13/20
# 56/56 [==============================] - 74s 1s/step - loss: -260491808.0000 - accuracy: 0.1724 - val_loss: -91566080.0000 - val_accuracy: 0.1499
# Epoch 14/20
# 56/56 [==============================] - 74s 1s/step - loss: -321652992.0000 - accuracy: 0.1724 - val_loss: -255858800.0000 - val_accuracy: 0.1499
# Epoch 15/20
# 56/56 [==============================] - 74s 1s/step - loss: -396972320.0000 - accuracy: 0.1724 - val_loss: -227423680.0000 - val_accuracy: 0.1499
# Epoch 16/20
# 56/56 [==============================] - 74s 1s/step - loss: -477385152.0000 - accuracy: 0.1724 - val_loss: -432673536.0000 - val_accuracy: 0.1499
# Epoch 17/20
# 56/56 [==============================] - 73s 1s/step - loss: -567716224.0000 - accuracy: 0.1724 - val_loss: -869193792.0000 - val_accuracy: 0.1499
# Epoch 18/20
# 56/56 [==============================] - 73s 1s/step - loss: -666469440.0000 - accuracy: 0.1724 - val_loss: -540477952.0000 - val_accuracy: 0.1499
# Epoch 19/20
# 56/56 [==============================] - 73s 1s/step - loss: -774865472.0000 - accuracy: 0.1724 - val_loss: -554099008.0000 - val_accuracy: 0.1499
# Epoch 20/20
# 56/56 [==============================] - 74s 1s/step - loss: -901274944.0000 - accuracy: 0.1724 - val_loss: -512524224.0000 - val_accuracy: 0.1499

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']


epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
loss, accuracy = model.evaluate(train_ds, verbose=1,)
loss_v, accuracy_v = model.evaluate(val_ds, verbose=1)

print("Accuracy: ", accuracy)
print("Validation Accuracy: ",accuracy_v)
print("Loss: ",loss)
print("Validation Loss", loss_v)


# Thus we can clearly that model Overfit and we need to chose right data augumentation strategy
# Out:
# 56/56 [==============================] - 12s 208ms/step - loss: -508423648.0000 - accuracy: 0.1724
# 14/14 [==============================] - 3s 194ms/step - loss: -512524224.0000 - accuracy: 0.1499
# Accuracy:  0.1724330335855484
# Validation Accuracy:  0.14988814294338226
# Loss:  -508423648.0
# Validation Loss -512524224.0

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images

image_class = ['nevus','melanoma','basal_cell_caricoma','actinic_keratosis','vasc_lesion','dermatofibroma', 'pigmented_keratosis', 'seborrheic_keratosis', 'squamous_carci']

train_batches = datagen.flow_from_directory(data_dir_train, 
    target_size = (180,180),
    classes = image_class,
    batch_size = 64
 )

valid_batches = datagen.flow_from_directory(data_dir_test, 
    target_size = (180,180),
    classes = image_class,
    batch_size = 64
)
# Out:
# Found 890 images belonging to 9 classes.
# Found 48 images belonging to 9 classes.

# %%
# visualize how your augmentation strategy works for one instance of training image.
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings


model = Sequential()

# Increse the model size by adding another 32 layer
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same', input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))
# Max Pool size of 2*2
model.add(MaxPool2D(pool_size=(2, 2)))
# Adding Dropout Layer
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(9, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 180, 180, 32)      896
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 180, 180, 32)      9248
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 90, 90, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 90, 90, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 90, 90, 64)        18496
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 90, 90, 64)        36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 45, 45, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 45, 45, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 43, 43, 128)       73856
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 21, 21, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 21, 21, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 56448)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               28901888
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 9)                 4617
# =================================================================
# Total params: 29,045,929
# Trainable params: 29,045,929
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model.compile(loss='categorical_crossentropy',
                  optimizer=optimizer,
                  metrics=['accuracy'])

# %%
# Set a learning rate annealer
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
    patience=3, 
    verbose=1, 
    factor=0.5, 
    min_lr=0.00001)

# %%
pip install git+git://github.com/fchollet/keras.git
# Out:
# Collecting git+git://github.com/fchollet/keras.git
#   Cloning git://github.com/fchollet/keras.git to c:\users\pratik\appdata\local\temp\pip-req-build-cw_31npz
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet git://github.com/fchollet/keras.git 'C:\Users\Pratik\AppData\Local\Temp\pip-req-build-cw_31npz'
#   fatal: unable to connect to github.com:
#   github.com[0: 20.207.73.82]: errno=Unknown error
#
#   error: subprocess-exited-with-error
#
#   git clone --filter=blob:none --quiet git://github.com/fchollet/keras.git 'C:\Users\Pratik\AppData\Local\Temp\pip-req-build-cw_31npz' did not run successfully.
#   exit code: 128
#
#   See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# git clone --filter=blob:none --quiet git://github.com/fchollet/keras.git 'C:\Users\Pratik\AppData\Local\Temp\pip-req-build-cw_31npz' did not run successfully.
# exit code: 128
#
# See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
## Your code goes here, note: train your model for 20 epochs
epochs = 20
batch_size = 10
history = model.fit(train_batches,
  epochs = epochs, verbose = 1, validation_data=valid_batches , callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/20
# 14/14 [==============================] - 49s 3s/step - loss: 119.6184 - accuracy: 0.4079 - val_loss: 1.5585 - val_accuracy: 0.2917
# Epoch 2/20
# 14/14 [==============================] - 43s 3s/step - loss: 1.1811 - accuracy: 0.3730 - val_loss: 1.5538 - val_accuracy: 0.3333
# Epoch 3/20
# 14/14 [==============================] - 43s 3s/step - loss: 1.0518 - accuracy: 0.4551 - val_loss: 1.5744 - val_accuracy: 0.2917
# Epoch 4/20
# 14/14 [==============================] - 43s 3s/step - loss: 1.0027 - accuracy: 0.4865 - val_loss: 1.5353 - val_accuracy: 0.3333
# Epoch 5/20
# 14/14 [==============================] - ETA: 0s - loss: 0.9673 - accuracy: 0.4944
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 14/14 [==============================] - 43s 3s/step - loss: 0.9673 - accuracy: 0.4944 - val_loss: 1.5488 - val_accuracy: 0.3333
# Epoch 6/20
# 14/14 [==============================] - 43s 3s/step - loss: 0.9512 - accuracy: 0.5292 - val_loss: 1.5359 - val_accuracy: 0.3333
# Epoch 7/20
# 14/14 [==============================] - 44s 3s/step - loss: 0.9542 - accuracy: 0.5213 - val_loss: 1.4909 - val_accuracy: 0.3333
# Epoch 8/20
# 14/14 [==============================] - 45s 3s/step - loss: 0.9154 - accuracy: 0.5539 - val_loss: 1.4468 - val_accuracy: 0.3542
# Epoch 9/20
# 14/14 [==============================] - 47s 3s/step - loss: 0.9090 - accuracy: 0.5742 - val_loss: 1.4349 - val_accuracy: 0.3333
# Epoch 10/20
# 14/14 [==============================] - 44s 3s/step - loss: 0.9012 - accuracy: 0.5910 - val_loss: 1.4063 - val_accuracy: 0.3333
# Epoch 11/20
# 14/14 [==============================] - ETA: 0s - loss: 0.8685 - accuracy: 0.6034
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 14/14 [==============================] - 44s 3s/step - loss: 0.8685 - accuracy: 0.6034 - val_loss: 1.4119 - val_accuracy: 0.3333
# Epoch 12/20
# 14/14 [==============================] - 47s 3s/step - loss: 0.8376 - accuracy: 0.6326 - val_loss: 1.3505 - val_accuracy: 0.3333
# Epoch 13/20
# 14/14 [==============================] - 47s 3s/step - loss: 0.8473 - accuracy: 0.6270 - val_loss: 1.3507 - val_accuracy: 0.3333
# Epoch 14/20
# 14/14 [==============================] - ETA: 0s - loss: 0.7936 - accuracy: 0.6618
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 14/14 [==============================] - 46s 3s/step - loss: 0.7936 - accuracy: 0.6618 - val_loss: 1.3032 - val_accuracy: 0.3333
# Epoch 15/20
# 14/14 [==============================] - 46s 3s/step - loss: 0.7759 - accuracy: 0.6708 - val_loss: 1.2674 - val_accuracy: 0.3750
# Epoch 16/20
# 14/14 [==============================] - 47s 3s/step - loss: 0.7665 - accuracy: 0.6494 - val_loss: 1.2492 - val_accuracy: 0.3958
# Epoch 17/20
# 14/14 [==============================] - 50s 4s/step - loss: 0.7475 - accuracy: 0.6697 - val_loss: 1.2275 - val_accuracy: 0.4583
# Epoch 18/20
# 14/14 [==============================] - 51s 4s/step - loss: 0.7491 - accuracy: 0.6775 - val_loss: 1.2250 - val_accuracy: 0.4167
# Epoch 19/20
# 14/14 [==============================] - 49s 4s/step - loss: 0.7163 - accuracy: 0.6854 - val_loss: 1.2361 - val_accuracy: 0.4583
# Epoch 20/20
# 14/14 [==============================] - 50s 4s/step - loss: 0.7262 - accuracy: 0.6708 - val_loss: 1.2442 - val_accuracy: 0.4792

# %%
acc = history.history['accuracy']
print(history.history.keys, ":")
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# <built-in method keys of dict object at 0x000002958F299780> :

# %%
loss, accuracy = model.evaluate(train_ds, verbose=1,)
loss_v, accuracy_v = model.evaluate(val_ds, verbose=1)

print("Accuracy: ", accuracy)
print("Validation Accuracy: ",accuracy_v)
print("Loss: ",loss)
print("Validation Loss", loss_v)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 loss, accuracy = model.evaluate(train_ds, verbose=1,)
#       2 loss_v, accuracy_v = model.evaluate(val_ds, verbose=1)
#       4 print("Accuracy: ", accuracy)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py:108, in enable_multi_worker.<locals>._method_wrapper(self, *args, **kwargs)
#     106 def _method_wrapper(self, *args, **kwargs):
#     107   if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108     return method(self, *args, **kwargs)
#     110   # Running inside `run_distribute_coordinator` already.
#     111   if dc_context.get_current_worker_context():
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py:1379, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict)
#    1377 with trace.Trace('TraceContext', graph_type='test', step_num=step):
#    1378   callbacks.on_test_batch_begin(step)
# -> 1379   tmp_logs = test_function(iterator)
#    1380   if data_handler.should_sync:
#    1381     context.async_wait()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\def_function.py:780, in Function.__call__(self, *args, **kwds)
#     778 else:
#     779   compiler = "nonXla"
# --> 780   result = self._call(*args, **kwds)
#     782 new_tracing_count = self._get_tracing_count()
#     783 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\def_function.py:814, in Function._call(self, *args, **kwds)
#     811 self._lock.release()
#     812 # In this case we have not created variables on the first call. So we can
#     813 # run the first trace but we should fail if variables are created.
# --> 814 results = self._stateful_fn(*args, **kwds)
#     815 if self._created_variables:
#     816   raise ValueError("Creating variables on a non-first call to a function"
#     817                    " decorated with tf.function.")
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py:2828, in Function.__call__(self, *args, **kwargs)
#    2826 """Calls a graph function specialized to the inputs."""
#    2827 with self._lock:
# -> 2828   graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
#    2829 return graph_function._filtered_call(args, kwargs)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py:3210, in Function._maybe_define_function(self, args, kwargs)
#    3200 with ag_ctx.ControlStatusCtx(
#    3201     status=ag_status, options=self._autograph_options):
#    3202
#    (...)
#    3205   # and 2. there's no provided input signature
#    3206   # and 3. there's been a cache miss for this calling context
#    3207   if (self._experimental_relax_shapes
#    3208       and self.input_signature is None
#    3209       and call_context_key in self._function_cache.missed):
# -> 3210     return self._define_function_with_shape_relaxation(args, kwargs)
#    3212   self._function_cache.missed.add(call_context_key)
#    3213   graph_function = self._create_graph_function(args, kwargs)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py:3141, in Function._define_function_with_shape_relaxation(self, args, kwargs)
#    3134   (relaxed_arg_specs, relaxed_kwarg_specs) = nest.pack_sequence_as(
#    3135       (args, kwargs), relaxed_arg_specs, expand_composites=False)
#    3136   (args, kwargs) = nest.pack_sequence_as(
#    3137       (relaxed_arg_specs, relaxed_kwarg_specs),
#    3138       nest.flatten((args, kwargs), expand_composites=True),
#    3139       expand_composites=True)
# -> 3141 graph_function = self._create_graph_function(
#    3142     args, kwargs, override_flat_arg_shapes=relaxed_arg_shapes)
#    3143 self._function_cache.arg_relaxed[rank_only_cache_key] = graph_function
#    3145 return graph_function, args, kwargs
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py:3065, in Function._create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3060 missing_arg_names = [
#    3061     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    3062 ]
#    3063 arg_names = base_arg_names + missing_arg_names
#    3064 graph_function = ConcreteFunction(
# -> 3065     func_graph_module.func_graph_from_py_func(
#    3066         self._name,
#    3067         self._python_function,
#    3068         args,
#    3069         kwargs,
#    3070         self.input_signature,
#    3071         autograph=self._autograph,
#    3072         autograph_options=self._autograph_options,
#    3073         arg_names=arg_names,
#    3074         override_flat_arg_shapes=override_flat_arg_shapes,
#    3075         capture_by_value=self._capture_by_value),
#    3076     self._function_attributes,
#    3077     function_spec=self.function_spec,
#    3078     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    3079     # scope. This is not the default behavior since it gets used in some
#    3080     # places (like Keras) where the FuncGraph lives longer than the
#    3081     # ConcreteFunction.
#    3082     shared_func_graph=False)
#    3083 return graph_function
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\framework\func_graph.py:986, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     983 else:
#     984   _, original_func = tf_decorator.unwrap(python_func)
# --> 986 func_outputs = python_func(*func_args, **func_kwargs)
#     988 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#     989 # TensorArrays and `None`s.
#     990 func_outputs = nest.map_structure(convert, func_outputs,
#     991                                   expand_composites=True)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\def_function.py:600, in Function._defun_with_scope.<locals>.wrapped_fn(*args, **kwds)
#     585 # We register a variable creator with reduced priority. If an outer
#     586 # variable creator is just modifying keyword arguments to the variable
#     587 # constructor, this will work harmoniously. Since the `scope` registered
#    (...)
#     595 # better than the alternative, tracing the initialization graph but giving
#     596 # the user a variable type they didn't want.
#     597 with ops.get_default_graph()._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     598   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     599   # the function a weak reference to itself to avoid a reference cycle.
# --> 600   return weak_wrapped_fn().__wrapped__(*args, **kwds)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\framework\func_graph.py:973, in func_graph_from_py_func.<locals>.wrapper(*args, **kwargs)
#     971 except Exception as e:  # pylint:disable=broad-except
#     972   if hasattr(e, "ag_error_metadata"):
# --> 973     raise e.ag_error_metadata.to_exception(e)
#     974   else:
#     975     raise
#
# ValueError: in user code:
#
#     C:\Users\Pratik\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py:1224 test_function  *
#         return step_function(self, iterator)
#     C:\Users\Pratik\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py:1215 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     C:\Users\Pratik\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\distribute\distribute_lib.py:1211 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     C:\Users\Pratik\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\distribute\distribute_lib.py:2585 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     C:\Users\Pratik\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\distribute\distribute_lib.py:2945 _call_for_each_replica
#         return fn(*args, **kwargs)
#     C:\Users\Pratik\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py:1208 run_step  **
#         outputs = model.test_step(data)
#     C:\Users\Pratik\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py:1176 test_step
#         self.compiled_loss(
#     C:\Users\Pratik\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\compile_utils.py:204 __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     C:\Users\Pratik\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\losses.py:149 __call__
#         losses = ag_call(y_true, y_pred)
#     C:\Users\Pratik\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\losses.py:253 call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     C:\Users\Pratik\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\util\dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     C:\Users\Pratik\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\losses.py:1535 categorical_crossentropy
#         return K.categorical_crossentropy(y_true, y_pred, from_logits=from_logits)
#     C:\Users\Pratik\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\util\dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     C:\Users\Pratik\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\backend.py:4687 categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#     C:\Users\Pratik\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\framework\tensor_shape.py:1134 assert_is_compatible_with
#         raise ValueError("Shapes %s and %s are incompatible" % (self, other))
#
#     ValueError: Shapes (None, 1) and (None, 9) are incompatible

# %%
import matplotlib.pyplot as plt
data = dict()

for i in class_names:
  data[i] = []

plt.figure(figsize=(10, 10))
for images, labels in train_ds:
  for i in range(9):
    data[class_names[labels[i]]].append(images[i].numpy().astype("uint8"))

for i in data:
  data[i] = len(data[i]) 

f = plt.figure()
f.set_figwidth(20)
f.set_figheight(20)

plt.bar(range(len(data)), list(data.values()), align='center')
plt.xticks(range(len(data)), list(data.keys()))
plt.show()

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.10-py2.py3-none-any.whl (38 kB)
# Collecting future>=0.16.0
#   Downloading future-0.18.2.tar.gz (829 kB)
#      -------------------------------------- 829.2/829.2 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: tqdm>=4.9.0 in c:\users\pratik\anaconda3\envs\project\lib\site-packages (from Augmentor) (4.64.0)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\pratik\anaconda3\envs\project\lib\site-packages (from Augmentor) (9.2.0)
# Requirement already satisfied: numpy>=1.11.0 in c:\users\pratik\anaconda3\envs\project\lib\site-packages (from Augmentor) (1.23.2)
# Requirement already satisfied: colorama in c:\users\pratik\anaconda3\envs\project\lib\site-packages (from tqdm>=4.9.0->Augmentor) (0.4.5)
# Building wheels for collected packages: future
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491058 sha256=481d4103676ebd921318166824abc0cfff361d04470ffbf522b3fee9a4506bc0
#   Stored in directory: c:\users\pratik\appdata\local\pip\cache\wheels\8e\70\28\3d6ccd6e315f65f245da085482a2e1c7d14b90b30f239e2cf4
# Successfully built future
# Installing collected packages: future, Augmentor
# Successfully installed Augmentor-0.2.10 future-0.18.2

# %%
path_to_training_dataset="/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/"
# data_dir_train = pathlib.Path(root_path + '/Train')
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [29], in <cell line: 4>()
#       3 import Augmentor
#       4 for i in class_names:
# ----> 5     p = Augmentor.Pipeline(path_to_training_dataset + i)
#       6     p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
#       7     p.sample(500)
#
# File ~\anaconda3\envs\project\lib\site-packages\Augmentor\Pipeline.py:87, in Pipeline.__init__(self, source_directory, output_directory, save_format)
#      84 self.process_ground_truth_images = False
#      86 if source_directory is not None:
# ---> 87     self._populate(source_directory=source_directory,
#      88                    output_directory=output_directory,
#      89                    ground_truth_directory=None,
#      90                    ground_truth_output_directory=output_directory)
#
# File ~\anaconda3\envs\project\lib\site-packages\Augmentor\Pipeline.py:135, in Pipeline._populate(self, source_directory, output_directory, ground_truth_directory, ground_truth_output_directory)
#     133 # Check if the source directory for the original images to augment exists at all
#     134 if not os.path.exists(source_directory):
# --> 135     raise IOError("The source directory you specified does not exist.")
#     137 # If a ground truth directory is being specified we will check here if the path exists at all.
#     138 if ground_truth_directory:
#
# OSError: The source directory you specified does not exist.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)

# %%
path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = df2

# %%
new_df['Label'].value_counts()

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
data_dir_train="/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
model = Sequential()

# Increse the model size by adding another 32 layer
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same', input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))

# Max Pool size of 2*2
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(BatchNormalization())
# Adding Dropout Layer
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 180, 180, 32)      896
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 180, 180, 32)      9248
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 90, 90, 32)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 90, 90, 32)        128
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 90, 90, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 90, 90, 64)        18496
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 90, 90, 64)        36928
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 45, 45, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 45, 45, 64)        256
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 45, 45, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 43, 43, 128)       73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 43, 43, 128)       512
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 21, 21, 128)       0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 21, 21, 128)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 56448)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               7225472
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 7,366,433
# Trainable params: 7,365,729
# Non-trainable params: 704
# _________________________________________________________________

# %%
optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model.compile(loss='categorical_crossentropy',
                  optimizer=optimizer,
                  metrics=['accuracy'])

# %%
epochs = 50

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
    patience=3, 
    verbose=1, 
    factor=0.5, 
    min_lr=0.00001)

batch_size = 10
history = model.fit(train_ds,
  epochs = epochs, verbose = 1, validation_data=val_ds , callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/50
# 56/56 [==============================] - 110s 2s/step - loss: 0.0000e+00 - accuracy: 0.1724 - val_loss: 0.0000e+00 - val_accuracy: 0.1499
# Epoch 2/50
# 56/56 [==============================] - 103s 2s/step - loss: 0.0000e+00 - accuracy: 0.1724 - val_loss: 0.0000e+00 - val_accuracy: 0.1499
# Epoch 3/50
# 56/56 [==============================] - 106s 2s/step - loss: 0.0000e+00 - accuracy: 0.1724 - val_loss: 0.0000e+00 - val_accuracy: 0.1499
# Epoch 4/50
# 56/56 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1724
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 56/56 [==============================] - 102s 2s/step - loss: 0.0000e+00 - accuracy: 0.1724 - val_loss: 0.0000e+00 - val_accuracy: 0.1499
# Epoch 5/50
# 56/56 [==============================] - 102s 2s/step - loss: 0.0000e+00 - accuracy: 0.1724 - val_loss: 0.0000e+00 - val_accuracy: 0.1499
# Epoch 6/50
# 56/56 [==============================] - 106s 2s/step - loss: 0.0000e+00 - accuracy: 0.1724 - val_loss: 0.0000e+00 - val_accuracy: 0.1499
# Epoch 7/50
# 56/56 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1724
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 56/56 [==============================] - 101s 2s/step - loss: 0.0000e+00 - accuracy: 0.1724 - val_loss: 0.0000e+00 - val_accuracy: 0.1499
# Epoch 8/50
# 56/56 [==============================] - 106s 2s/step - loss: 0.0000e+00 - accuracy: 0.1724 - val_loss: 0.0000e+00 - val_accuracy: 0.1499
# Epoch 9/50
# 56/56 [==============================] - 107s 2s/step - loss: 0.0000e+00 - accuracy: 0.1724 - val_loss: 0.0000e+00 - val_accuracy: 0.1499
# Epoch 10/50
# 56/56 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1724
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 56/56 [==============================] - 104s 2s/step - loss: 0.0000e+00 - accuracy: 0.1724 - val_loss: 0.0000e+00 - val_accuracy: 0.1499
# Epoch 11/50
# 56/56 [==============================] - 105s 2s/step - loss: 0.0000e+00 - accuracy: 0.1724 - val_loss: 0.0000e+00 - val_accuracy: 0.1499
# Epoch 12/50
# 56/56 [==============================] - 104s 2s/step - loss: 0.0000e+00 - accuracy: 0.1724 - val_loss: 0.0000e+00 - val_accuracy: 0.1499
# Epoch 13/50
# 56/56 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1724
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 56/56 [==============================] - 104s 2s/step - loss: 0.0000e+00 - accuracy: 0.1724 - val_loss: 0.0000e+00 - val_accuracy: 0.1499
# Epoch 14/50
# 56/56 [==============================] - 104s 2s/step - loss: 0.0000e+00 - accuracy: 0.1724 - val_loss: 0.0000e+00 - val_accuracy: 0.1499
# Epoch 15/50
# 56/56 [==============================] - 105s 2s/step - loss: 0.0000e+00 - accuracy: 0.1724 - val_loss: 0.0000e+00 - val_accuracy: 0.1499
# Epoch 16/50
# 56/56 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1724
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 56/56 [==============================] - 107s 2s/step - loss: 0.0000e+00 - accuracy: 0.1724 - val_loss: 0.0000e+00 - val_accuracy: 0.1499
# Epoch 17/50
# 56/56 [==============================] - 109s 2s/step - loss: 0.0000e+00 - accuracy: 0.1724 - val_loss: 0.0000e+00 - val_accuracy: 0.1499
# Epoch 18/50
# 56/56 [==============================] - 109s 2s/step - loss: 0.0000e+00 - accuracy: 0.1724 - val_loss: 0.0000e+00 - val_accuracy: 0.1499
# Epoch 19/50
# 56/56 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1724
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 56/56 [==============================] - 101s 2s/step - loss: 0.0000e+00 - accuracy: 0.1724 - val_loss: 0.0000e+00 - val_accuracy: 0.1499
# Epoch 20/50
# 32/56 [================>.............] - ETA: 40s - loss: 0.0000e+00 - accuracy: 0.1777

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
